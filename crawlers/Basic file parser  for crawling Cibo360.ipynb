# %%
from tinycrawler import TinyCrawler, Log, Statistics
from bs4 import BeautifulSoup, SoupStrainer
import pandas as pd
import requests
from requests import Response
from urllib.parse import urlparse

import os
import json
import bs4
import pandas as pd


def html_sanitization(html: str) -> str:
    """Return sanitized html."""
    return html.replace("⌊", "")


def get_product_name(response: Response) -> str:
    """Return product name from given Response object."""
    name = bs4.BeautifulSoup(response.text).find("h1").get_text()
    print(name)
    return name


def parse_tables(html: str, path: str, strainer: SoupStrainer):
    """Parse table at given strained html object saving them as csv at given path."""
    for table in BeautifulSoup(html, "lxml", parse_only=strainer)("table"):
        df = pd.read_html(html_sanitization(str(table)))[0]
        table_name = df[0][0].lower().strip().replace(" ","_")
        df = df.drop(0)
        df = df.set_index(0)
        df.to_csv("{path}/{table_name}.csv".format(path=path, table_name=table_name))


def parse(response: Response):
    path = "{root}/{product}".format(
        root=urlparse(response.url).netloc, product=get_product_name(response))
    if not os.path.exists(path):
        os.makedirs(path)
    parse_tables(
        response.text, path,
        SoupStrainer(
            "table"))

# %%
url = "https://www.cibo360.it/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&CODE=000090"
parse(requests.get(url))
# Out:
#  Orzo perlato (Hordeum vulgare)

# %%
text = requests.get("https://www.cibo360.it/cgi-bin/db/datafind1.cgi").text

# %%
bs4.BeautifulSoup(text)("a")
# Out:
# [<a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=407010">Liquori da dessert</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=009110">Margarina -2/3 di grassi animali, 1/3 di grassi vegetali</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106270">Pollo, ala con pelle cruda</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005506">Melanzane, cotte [saltate in padella senza aggiunta di grassi e di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=122410">Salmone, affumicato</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106913">Tacchino, fuso, senza pelle, cotto [in forno senza aggiunta di grassi e di sale e scolato dal grasso prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005600">Peperoni crudi</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=208520">Crostata con marmellata di albicocche, tipo industriale</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=119010">Big-burger -peso medio 191g- [Pane all'olio o al latte, doppio hamburger di carne bovina, ketchup, verdure]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=185010">Uova di oca, intero</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=121800">Pagello</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000510">Pane di segale</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005730">Zucchine</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=160300">Formaggi magri</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=166810">Ricotta di pecora</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=006511">Patate, cotte [arrosto]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000090">Orzo perlato</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007600">Papaia</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=004105">Fagioli, cotti [bolliti in acqua distillata senza aggiunta di sale e scolati]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=166000">Parmigiano</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=004406">Fave fresche, cotte [saltate in padella senza aggiunta di grassi e di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000870">Pasta all'uovo secca</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=108015">Cinghiale [tessuto muscolare privato del grasso visibile]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=114040">PatÌ di prosciutto</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106020">Faraona, coscio, con pelle, crudo</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=115340">Fegato di equino</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=115500">Milza di bovino</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007250">Nespole</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=105600">Maiale, pesante, coscio</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=006660">Pomodori, conserva</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=401100">Bevanda tipo cola</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=110195">Cotechino, confezionato precotto, [bollito per 20 min. dentro la confezione e scolato dal liquido prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=105800">Maiale, pesante, spalla</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=900310">Minestre in scatola, crema di pollo</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005210">Cavolo verza crudo</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=104040">Agnello, costoletta cruda [tessuto muscolare privato del grasso visibile]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=120250">Anguilla d'allevamento, filetti</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=109510">Rana</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005330">Fiori di zucca</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106600">Pollo, sovracoscio con pelle crudo</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007410">Uva, secca</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000550">Pane di tipo integrale</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000210">Farina di frumento</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106506">Pollo, petto, cotto [saltato in padella senza aggiunta di grassi e di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005400">Indivia</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=161600">Edam</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=110200">Mortadella</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=166010">Caciottina mista</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=123000">Sgombro o maccarello fresco</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=121310">Melù o pesce molo  fresco</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000230">Farina di frumento tipo 0</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005670">Ravanelli</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000140">Sorgo</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000530">Pane di tipo 0</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005245">Cicoria di campo, cotta [bollita in acqua distillata senza aggiunta di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=105200">Maiale, leggero, coscio</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=210060">Merendine, tipo briosche</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=004510">Lenticchie in scatola, scolate</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=150010">Yogurt intero bianco</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=107019">Coniglio intero, cotto</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000980">Biscotti per l'infanzia</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=196600">Vitello, grasso separato</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=102000">Bufalo [tessuto muscolare privato del grasso visibile]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000720">Pizza con pomodoro e mozzarella</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005324">Finocchi, cotti [in forno a microonde senza aggiunta di acqua e di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=110400">Prosciutto cotto</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=008560">Noci con guscio</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007460">Ananas</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=120008">Pesce grasso, intero</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005500">Melanzane crude</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=121730">Orata fresca d'allevamento, filetti</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106413">Pollo, fuso senza pelle, cotto [in forno senza aggiunta di grassi e di sale e scolato dal grasso prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005450">Radicchio verde</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007350">Prugne gialle</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=124010">Trota, surgelata</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106613">Pollo, sovracoscio senza pelle, cotto [in forno senza aggiunta di grassi e di sale e scolato dal grasso prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=101190">Bovino adulto o vitellone - lombata - [tessuto muscolare privato del grasso visibile]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106963">Tacchino, sovracoscio, senza pelle, cotto [in forno senza aggiunta di grassi e di sale e scolato dal grasso prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=000805">Pasta di semola, cotta [bollita in acqua distillata senza aggiunta di sale e scolata]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=106603">Pollo, sovracoscio con pelle, cotto [in forno senza aggiunta di grassi e di sale e scolato dal grasso prodotto con la cottura]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007190">Mele, disidratate</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=004720">Piselli in scatola, scolati</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=008930">Succo di frutta</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=135510">Latte di vacca, condensato zuccherato</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=009200">Olio di oliva</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=101260">Bovino adulto o vitellone - spalla, muscolo, girello, fesone- [tessuto muscolare privato del grasso visibile]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=135610">Latte di vacca in polvere, intero</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=122200">Razza</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007040">Cocomero</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=005634">Peperoni, rossi cotti [in forno a microonde senza aggiunta di acqua e di sale]</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=008550">Nocciole secche, con guscio</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=206820">Gelato alla frutta senza latte</a>,
#  <a href="/cgi-bin/db/post_vn1.cgi?ID_UTENTE=&amp;CODE=007110">Mele fresche</a>,
#  <a h="">r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   6   1   2   0   0   "   &gt;   D   o   l   c   e       v   e   r   d   e   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   2   0   2   3   0   "   &gt;   A   n   g   u   i   l   l   a       d   i       f   i   u   m   e   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   0   0   8   5   8   0   "   &gt;   N   o   c   i       p   e   c   a   n       c   o   n       g   u   s   c   i   o   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   1   9   9   5   0   "   &gt;   Z   a   m   p   o   n   e   ,       c   o   n   f   e   z   i   o   n   a   t   o   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   0   0   7   1   7   0   "   &gt;   M   e   l   e       f   r   e   s   c   h   e       -       i   m   p   e   r   a   t   o   r   e   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   2   0   5   0   0   "   &gt;   C   a   r   p   a   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   0   0   7   3   3   0   "   &gt;   P   e   s   c   h   e   n   o   c   i   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   1   0   5   4   0   "   &gt;   P   r   o   s   c   i   u   t   t   o       c   r   u   d   o   ,       d   i   s   o   s   s   a   t   o   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   1   1   0   6   4   0   "   &gt;   S   a   l   a   m   e       M   i   l   a   n   o   /   a   &gt;   /   d   i   v   &gt;   d   i   v       c   l   a   s   s   =   c   o   n   t   e   n   t   &gt;   a       h   r   e   f   =   "   /   c   g   i   -   b   i   n   /   d   b   /   p   o   s   t   _   v   n   1   .   c   g   i   ?   I   D   _   U   T   E   N   T   E   =   &amp;C   O   D   E   =   0   0   1   0   1   0   "   &gt;   C   r   a   c   k   e   r   s       a   l   l   a       s   o   i  ...
#     	   	   	   	   &amp;n   b   s   p   ;
#     	   	   	   	   /   t   d   &gt;   /   t   r   &gt;   /   t   a   b   l   e   &gt;   	   	   /   t   d   &gt;
#     	   	   	           /   t   r   &gt;
#     	   	   	   /   t   a   b   l   e   &gt;
#     	   	   	   t   a   b   l   e       c   e   l   l   s   p   a   c   i   n   g   =   0       c   e   l   l   p   a   d   d   i   n   g   =   0       w   i   d   t   h   =   7   5   0       b   o   r   d   e   r   =   0   &gt;
#     	   	   	           t   r   &gt;
#     	   	   	                   t   d       v   a   l   i   g   n   =   t   o   p       h   e   i   g   h   t   =   "   2   0   "       w   i   d   t   h   =   1   0   0       b   g   c   o   l   o   r   =   "   #   F   F   F   F   9   9   "   &gt;   &amp;n   b   s   p   ;   /   t   d   &gt;
#     	   	   	                   t   d       v   a   l   i   g   n   =   t   o   p       h   e   i   g   h   t   =   "   2   0   "       b   g   c   o   l   o   r   =   "   #   D   4   7   7   0   8   "   &gt;   i   m   g       s   r   c   =   "   /   i   m   a   g   e   s   /   c   a   l   c   o   l   o   _   c   a   l   o   r   i   e   /   b   o   t   t   o   m   _   b   a   r   .   g   i   f   "       w   i   d   t   h   =   "   6   5   0   "       h   e   i   g   h   t   =   "   2   0   "       u   s   e   m   a   p   =   "   #   m   e   n   u   _   b   o   t   t   o   m   "       b   o   r   d   e   r   =   "   0   "   &gt;   /   t   d   &gt;
#     	   	   	           /   t   r   &gt;
#     	   	   	   /   t   a   b   l   e   &gt;
#     	   	   	   /   b   o   d   y   &gt;
#     	   	   	   /   h   t   m   l   &gt;   </a>]

# %%
text
# Out:
# '<html>\n\t\t\t<head>\n\t\t\t<title>Cibo 360 - Database alimenti - Ricerca per alimento</title>\n\n\t\t\t<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n\t\t\t<link rel="stylesheet" href="/css/common.css" type="text/css">\n\t\t\t<link rel="stylesheet" href="/css/calcolo/calcolo.css" type="text/css">\t\t\t\n\t\t\t<link rel="stylesheet" href="/css/header.css" type="text/css">\n\t\t\t<link rel="stylesheet" href="/css/calcolo/database.css" type="text/css">\n\t\t\t<script language="JavaScript">\n\t\t\t<!--\n\t\t\tfunction MM_openBrWindow(theURL,winName,features) { //v2.0\n\t\t\t  window.open(theURL,winName,features);\n\t\t\t}\n\t\t\t//-->\n\t\t\t</script>\n\t\t</head>\n\t<BODY bgColor=#ffffff leftMargin=0 topMargin=0 MARGINWIDTH="0" MARGINHEIGHT="0" >\n\n\t<MAP name=menu_sec>\n\t  <AREA shape=RECT alt="Contacalorie" coords=4,45,95,67\n\thref="/cgi-bin/login1.cgi?LOGIN=CONTA&ID_UTENTE=">\n\t  <AREA shape=RECT alt="Calcola Ricetta" coords=120,43,182,66\n\thref="/cgi-bin/login1.cgi?LOGIN=CONTA_RIC&ID_UTENTE=">\n\t  <area shape=RECT alt="Cerca Ricetta" coords=199,44,261,67\n\thref="/cgi-bin/login1.cgi?LOGIN=CERCA_RIC&ID_UTENTE=">\n\t  <AREA shape=RECT alt="Guida di Dieta Manager" coords=288,44,400,67\n\thref="/calcolo/guida/index.htm" target=_blank>\n\t</MAP>\n\n<MAP name=menu_bottom>\n  <area shape=rect coords=458,4,533,17 href="/catalogo/index.php" alt=I nostri prodotti title="I nostri prodotti">\n  <area shape=rect coords=189,5,274,16 href="mailto:infocibo360.it" alt="Contattaci" title="Contattaci">\n  <area shape=rect coords=5,5,50,17 href="https://www.cibo360.it" alt="Cibo 360!" title="Cibo 360!">\n  <area shape=rect coords=78,5,151,16 href="/autori/index.htm" alt="Scopri il nostro progetto editoriale!" title="Scopri il nostro progetto editoriale!">\n</MAP>\n\n<map name=Map>\n  <area shape="rect" coords="376,2,447,17" href="/catalogo/index.php" alt="Il catalogo" title="Il catalogo">\n  <area shape="rect" coords="146,2,227,17" href="mailto:info@cibo360.it" alt="Email" title="Email">\n  <area shape="rect" coords="58,2,127,17" href="/autori/index.htm" alt="Chi siamo" title="Chi siamo">  <area shape="rect" coords="3,2,43,17" href="/" alt="Home page" title="Home page">\n</map>\n\n<map name=menu_left>\n  <area shape=RECT alt="Viaggi" coords=4,365,52,380\nhref="/wellness_gourmet/viaggi/index.htm" title="Sport">\n  <area shape=RECT alt="Produttori" coords=5,344,78,356\nhref="/wellness_gourmet/produttori/index.htm" title="Produttori">\n\n  <area shape=RECT alt="Alimentazione" coords=3,245,93,258\nhref="/alimentazione/index.htm" title="Alimentazione">\n  <area shape=RECT alt="Coscienza Alimentare Online" coords=0,173,86,211\nhref="/cca.php" title="Coscienza Alimentare Online">\n  <area shape=RECT alt="Scrivici" coords=3,45,58,59\nhref="mailto:info@cibo360.it" title="Scrivici">\n  <area shape=RECT alt="Chi siamo" coords=3,26,78,40\nhref="/autori/index.htm" title="Chi siamo">\n  <area shape=RECT alt="Home page" coords=3,6,53,19\nhref="/" title="Home page">\n  <area shape=RECT alt="Sport" coords=4,385,52,400\nhref="/sport/index.htm" title="Sport">\n  <area shape=RECT alt="Dieta" coords=3,265,93,278\nhref="/dieta/dieta.htm" title="Dieta">\n  <area shape=RECT alt="Cibo&amp;Salute" coords=5,284,92,297\nhref="/cibo_salute/index.htm" title="Cibo e salute">\n  <area shape=RECT alt="Qualità" coords=6,324,54,339\nhref="/qualita/index.htm">\n  <area shape=RECT alt="Il catalogo" coords=5,85,74,101\nhref="/catalogo/index.php" title="Il catalogo">\n  <area shape=RECT alt="Cucina" coords=3,304,51,319\nhref="/cucina/index.htm" title="Cucina">\n  <area shape=RECT alt="Cucina Sì Online" coords=2,135,82,163\nhref="/ccasi.php" title="Cucina Sì Online">\n</map>\n\n    <div class=gghead>\n<script type="text/javascript"><!--\ngoogle_ad_client = "pub-0873783291449795";\ngoogle_ad_width = 728;\ngoogle_ad_height = 90;\ngoogle_ad_format = "728x90_as";\ngoogle_ad_type = "text";\ngoogle_ad_channel ="";\n//--></script>\n<script type="text/javasc ...
